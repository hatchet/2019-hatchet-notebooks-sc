# %%
import hatchet as ht
import sys

import pandas as pd

gf1 = ht.GraphFrame.from_literal([{
    'frame': {'name': 'main', 'type': 'function'},
    'metrics': {'time (inc)': 200.0, 'time': 40.0},
    'children': [
        {
            'frame': {'name': 'physics', 'type': 'function'},
            'metrics': {'time (inc)': 60.0, 'time': 40.0},
            'children': [
                {
                    'frame': {'name': 'mpi', 'type': 'function'},
                    'metrics': {'time (inc)': 20.0, 'time': 5.0},
                    'children': [
                        {
                            'frame': {'name': 'psm2', 'type': 'function'},
                            'metrics': {'time (inc)': 15.0, 'time': 15.0}
                        },
                    ]
                }
            ]
        },
        {
            'frame': {'name': 'solvers', 'type': 'function'},
            'metrics': {'time (inc)': 100.0, 'time': 0.0},
            'children': [
                {
                    'frame': {'name': 'hypre', 'type': 'function'},
                    'metrics': {'time (inc)': 65.0, 'time': 65.0},
                },
                {
                    'frame': {'name': 'mpi', 'type': 'function'},
                    'metrics': {'time (inc)': 35.0, 'time': 10.0},
                    'children': [
                        {
                            'frame': {'name': 'psm2', 'type': 'function'},
                            'metrics': {'time (inc)': 25.0, 'time': 25.0}
                        },
                    ]
                },
            ]
        },
    ]
}])

gf2 = ht.GraphFrame.from_literal([{
    'frame': {'name': 'main', 'type': 'function'},
    'metrics': {'time (inc)': 200.0, 'time': 40.0},
    'children': [
        {
            'frame': {'name': 'physics', 'type': 'function'},
            'metrics': {'time (inc)': 60.0, 'time': 40.0},
            'children': [
                {
                    'frame': {'name': 'mpi', 'type': 'function'},
                    'metrics': {'time (inc)': 20.0, 'time': 15.0},
                    'children': [
                        {
                            'frame': {'name': 'psm2', 'type': 'function'},
                            'metrics': {'time (inc)': 15.0, 'time': 30.0}
                        },
                    ]
                }
            ]
        },
        {
            'frame': {'name': 'solvers', 'type': 'function'},
            'metrics': {'time (inc)': 100.0, 'time': 0.0},
            'children': [
                {
                    'frame': {'name': 'hypre', 'type': 'function'},
                    'metrics': {'time (inc)': 65.0, 'time': 65.0},
                },
                {
                    'frame': {'name': 'mpi', 'type': 'function'},
                    'metrics': {'time (inc)': 35.0, 'time': 15.0},
                    'children': [
                        {
                            'frame': {'name': 'psm2', 'type': 'function'},
                            'metrics': {'time (inc)': 25.0, 'time': 35.0}
                        },
                    ]
                },
            ]
        },
    ]
}])

print(gf1.tree())
print(gf2.tree())
# Out:
#     __          __       __         __
#    / /_  ____ _/ /______/ /_  ___  / /_
#   / __ \/ __ `/ __/ ___/ __ \/ _ \/ __/
#  / / / / /_/ / /_/ /__/ / / /  __/ /_
# /_/ /_/\__,_/\__/\___/_/ /_/\___/\__/  v1.3.0
#
# 40.000 main
# ├─ 40.000 physics
# │  └─ 5.000 mpi
# │     └─ 15.000 psm2
# └─ 0.000 solvers
#    ├─ 65.000 hypre
#    └─ 10.000 mpi
#       └─ 25.000 psm2
#
# Legend (Metric: time)
# █ 58.50 - 65.00
# █ 45.50 - 58.50
# █ 32.50 - 45.50
# █ 19.50 - 32.50
# █ 6.50 - 19.50
# █ 0.00 - 6.50
#
# name User code    ◀  Only in left graph    ▶  Only in right graph
#
#     __          __       __         __
#    / /_  ____ _/ /______/ /_  ___  / /_
#   / __ \/ __ `/ __/ ___/ __ \/ _ \/ __/
#  / / / / /_/ / /_/ /__/ / / /  __/ /_
# /_/ /_/\__,_/\__/\___/_/ /_/\___/\__/  v1.3.0
#
# 40.000 main
# ├─ 40.000 physics
# │  └─ 15.000 mpi
# │     └─ 30.000 psm2
# └─ 0.000 solvers
#    ├─ 65.000 hypre
#    └─ 15.000 mpi
#       └─ 35.000 psm2
#
# Legend (Metric: time)
# █ 58.50 - 65.00
# █ 45.50 - 58.50
# █ 32.50 - 45.50
# █ 19.50 - 32.50
# █ 6.50 - 19.50
# █ 0.00 - 6.50
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
gf2 -= gf1

print(gf2.tree())
# Out:
#     __          __       __         __
#    / /_  ____ _/ /______/ /_  ___  / /_
#   / __ \/ __ `/ __/ ___/ __ \/ _ \/ __/
#  / / / / /_/ / /_/ /__/ / / /  __/ /_
# /_/ /_/\__,_/\__/\___/_/ /_/\___/\__/  v1.3.0
#
# 0.000 main
# ├─ 0.000 physics
# │  └─ 10.000 mpi
# │     └─ 15.000 psm2
# └─ 0.000 solvers
#    ├─ 0.000 hypre
#    └─ 5.000 mpi
#       └─ 10.000 psm2
#
# Legend (Metric: time)
# █ 13.50 - 15.00
# █ 10.50 - 13.50
# █ 7.50 - 10.50
# █ 4.50 - 7.50
# █ 1.50 - 4.50
# █ 0.00 - 1.50
#
# name User code    ◀  Only in left graph    ▶  Only in right graph
